# %%
df = read.csv('./Top-50-musicality-global.csv')

# %%
df
# Out:
#      X    Country Track.Name
# 1     0   Global  Standing Next to You
# 2     1   Global  greedy
# 3     2   Global  Si No EstÃ¡s
# 4     3   Global  Seven (feat. Latto) (Explicit Ver.)
# 5     4   Global  Is It Over Now? (Taylor's Version) (From The Vault)
# 6     5   Global  PERRO NEGRO
# 7     6   Global  Paint The Town Red
# 8     7   Global  Cruel Summer
# 9     8   Global  MONACO
# 10    9   Global  My Love Mine All Mine
# 11   10   Global  Strangers
# 12   11   Global  Water
# 13   12   Global  Now That We Don't Talk (Taylor's Version) (From The Vault)
# 14   13   Global  HARLEY QUINN
# 15   14   Global  3D (feat. Jack Harlow)
# 16   15   Global  QLONA
# 17   16   Global  Agora Hills
# 18   17   Global  Que Onda
# 19   18   Global  I Wanna Be Yours
# 20   19   Global  "Slut!" (Taylor's Version) (From The Vault)
# 21   20   Global  LALA
# 22   21   Global  SegÃºn QuiÃ©n
# 23   22   Global  Lollipop
# 24   23   Global  Daylight
# 25   24   Global  vampire
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Track Name', 'Artist Name', 'Album Name',
#        'Popularity', 'Date', 'Markets', 'Danceability', 'Acousticness',
#        'duration', 'Energy', 'Instrumentalness', 'Key', 'Liveness', 'Loudness',
#        'Mode', 'Speechiness', 'Tempo', 'TSignature', 'Positiveness'],
#       dtype='object')

# %%
df[['Danceability', 'Acousticness',
       'duration', 'Energy', 'Instrumentalness', 'Key', 'Liveness', 'Loudness',
       'Mode', 'Speechiness', 'Tempo', 'TSignature', 'Positiveness']].head()
# Out:
#    Danceability  Acousticness  duration  Energy  Instrumentalness  Key  \
# 0         0.711        0.0447    206020   0.809               0.0    2
# 1         0.750        0.2560    131872   0.733               0.0    6
# 2         0.537        0.8270    184061   0.421               0.0    5
# 3         0.790        0.3120    183551   0.831               0.0   11
# 4         0.596        0.0504    229478   0.658               0.0    0
#
#    Liveness  Loudness  Mode  Speechiness    Tempo  TSignature  Positiveness
# 0    0.3390    -4.389     0       0.0955  106.017           4         0.816
# 1    0.1140    -3.180     0       0.0319  111.018           1         0.844
# 2    0.1380    -8.720     1       0.0285   98.224           4         0.524
# 3    0.0797    -4.185     1       0.0440  124.987           4         0.872
# 4    0.1270    -7.346     1       0.0360  100.012           4         0.176
