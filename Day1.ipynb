# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\crkpn\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\crkpn\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\crkpn\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.drop(['speed1'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1087, 55)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df1=df[['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type',
    'opening_date_clean', 'speed_mph', 'height_value', 'Inversions_clean', 'Gforce_clean'
   ]].copy()

# %%
a=[1,2,3,4,5]

# %%
b=a.copy()
c=[1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a[0]=69

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %%
a
# Out:
# [69, 2, 3, 4, 5]

# %%
df1.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type                   object
# opening_date_clean     object
# speed_mph             float64
# height_value          float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df1['opening_date_clean']
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1082           NaN
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: object

# %%
df1['opening_date_clean']=pd.to_datetime(df1['opening_date_clean'])

# %%
df1.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type                          object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_value                 float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
df1 = df1.rename(columns={'coaster_name': 'Coaster_name', 'Location': 'Location', 'Status': 'Status', 'Manufacturer': 'Manufacturer', 'year_introduced': 'Year_introduced', 'latitude': 'Latitude', 'longitude': 'Longitude', 'Type': 'Type', 'opening_date_clean': 'Opening_date_clean', 'speed_mph': 'Speed_mph', 'height_value': 'Height_value', 'Inversions_clean': 'Inversions_clean', 'Gforce_clean': 'Gforce_clean'})

# %%
df1.isna()
# Out:
#       Coaster_name  Location  Status  Manufacturer  Year_introduced  Latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %% [markdown]
# ### checks if all the columns have duplicates

# %%
df1.loc[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_name, Location, Status, Manufacturer, Year_introduced, Latitude, Longitude, Type, Opening_date_clean, Speed_mph, Height_value, Inversions_clean, Gforce_clean]
# Index: []

# %%
df1.loc[df1.duplicated('coaster_name')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\crkpn\Documents\Programs\AIML\Koushik.ipynb Cell 30 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/crkpn/Documents/Programs/AIML/Koushik.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> df1.loc[df1.duplicated('coaster_name')]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:6806, in DataFrame.duplicated(self, subset, keep)
#    6804 diff = set(subset) - set(self.columns)
#    6805 if diff:
# -> 6806     raise KeyError(Index(diff))
#    6808 if len(subset) == 1 and self.columns.is_unique:
#    6809     # GH#45236 This is faster than get_group_index below
#    6810     result = self[subset[0]].duplicated(keep)
#
# KeyError: Index(['coaster_name'], dtype='object')

# %%
for i in range(len(list(df1['Coaster_name']))):
    if list(df1['Coaster_name'])[i]=='Crystal Beach Cyclone':
        print(i,list(df1['Coaster_name'])[i])
# Out:
# 39 Crystal Beach Cyclone
# 43 Crystal Beach Cyclone

# %%
df1.query('Coaster_name=="Crystal Beach Cyclone"')
# Out:
#              Coaster_name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_introduced  Latitude  Longitude  Type Opening_date_clean  Speed_mph  \
# 39             1926   42.8617   -79.0598  Wood         1926-01-01       60.0
# 43             1927   42.8617   -79.0598  Wood         1926-01-01       60.0
#
#     Height_value  Inversions_clean  Gforce_clean
# 39          96.0                 0           4.0
# 43          96.0                 0           4.0

# %% [markdown]
# ### Opening date is different for both

# %%
df1.loc[df1.duplicated(subset=['Coaster_name','Location','Opening_date_clean'])]
# Out:
#                             Coaster_name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df1.duplicated(subset=['Coaster_name','Location','Opening_date_clean']).sum()
# Out:
# 97

# %%
temp=df1.loc[~df1.duplicated(subset=['Coaster_name','Location','Opening_date_clean'])].reset_index()

# %%
temp
# Out:
#      index                            Coaster_name  \
# 0        0                      Switchback Railway
# 1        1                       Flip Flap Railway
# 2        2  Switchback Railway (Euclid Beach Park)
# 3        3            Loop the Loop (Coney Island)
# 4        4            Loop the Loop (Young's Pier)
# ..     ...                                     ...
# 985   1079            Ice Breaker (roller coaster)
# 986   1081                   Leviathan (Sea World)
# 987   1083               Pantheon (roller coaster)
# 988   1085                                 Tumbili
# 989   1086          Wonder Woman Flight of Courage
#
#                            Location              Status  \
# 0                      Coney Island             Removed
# 1                     Sea Lion Park             Removed
# 2    Cleveland, Ohio, United States              Closed
# 3                             Other             Removed
# 4                             Other             Removed
# ...

# %%
temp=df1.loc[~df1.duplicated(subset=['Coaster_name','Location','Opening_date_clean'])].reset_index(drop=True)

# %%
temp.head(45)
# Out:
#                               Coaster_name                         Location  \
# 0                       Switchback Railway                     Coney Island
# 1                        Flip Flap Railway                    Sea Lion Park
# 2   Switchback Railway (Euclid Beach Park)   Cleveland, Ohio, United States
# 3             Loop the Loop (Coney Island)                            Other
# 4             Loop the Loop (Young's Pier)                            Other
# 5                           Cannon Coaster                     Coney Island
# 6                            Leap-The-Dips                    Lakemont Park
# 7         Figure Eight (Euclid Beach Park)   Cleveland, Ohio, United States
# 8                             Drop the Dip                     Coney Island
# 9       Scenic Railway (Euclid Beach Park)   Cleveland, Ohio, United States
# 10          Loop the Loop (Olentangy Park)                   Olentangy Park
# ...

# %%
df1['Year_introduced'].value_counts()
# Out:
# 1999    49
# 2000    47
# 1998    32
# 2011    31
# 2001    30
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_introduced, Length: 101, dtype: int64

# %%
ax=df1['Year_introduced'].value_counts().head(10).plot(kind='bar',title="Top Year")
ax.set_xlabel('Year introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax=df1['Speed_mph'].plot(kind='hist',title="Speed")
ax.set_xlabel('Speed')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax=df1['Speed_mph'].plot(kind='hist',bins=20,title="Speed")
ax.set_xlabel('Speed')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax=df1['Speed_mph'].plot(kind='kde',title="Speed")
ax.set_xlabel('Speed')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
df1.plot(kind='scatter',
         x='Speed_mph',
                     y='Height_value')
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_value'>

# %%
ax = sns.scatterplot(x='Speed_mph',
                     y='Height_value',
                     hue='Year_introduced',
                     data=df1
                     )
ax.set_title("Coaster Speed vs Height")
plt.show()

# %%
df1.columns
# Out:
# Index(['Coaster_name', 'Location', 'Status', 'Manufacturer', 'Year_introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_date_clean', 'Speed_mph',
#        'Height_value', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
sns.pairplot(df1,
             vars=['Year_introduced','Speed_mph','Height_value'],
             hue="Type")

# %%
df_corr = df1[df1.columns].dropna().corr()
# Out:
# C:\Windows\Temp\ipykernel_18460\405085893.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df1[df1.columns].dropna().corr()

# %%
df_corr
# Out:
#                   Year_introduced  Latitude  Longitude  Speed_mph  \
# Year_introduced          1.000000 -0.086129   0.230257   0.196374
# Latitude                -0.086129  1.000000  -0.374223  -0.053048
# Longitude                0.230257 -0.374223   1.000000  -0.018461
# Speed_mph                0.196374 -0.053048  -0.018461   1.000000
# Height_value            -0.007362  0.045017  -0.313372   0.579053
# Inversions_clean         0.099290  0.008580  -0.005558   0.130034
# Gforce_clean             0.062081  0.060499   0.036979   0.544835
#
#                   Height_value  Inversions_clean  Gforce_clean
# Year_introduced      -0.007362          0.099290      0.062081
# Latitude              0.045017          0.008580      0.060499
# Longitude            -0.313372         -0.005558      0.036979
# Speed_mph             0.579053          0.130034      0.544835
# Height_value          1.000000          0.149724      0.326609
# ...

# %%
df1['Location'].value_counts()
# Out:
# Other                                 250
# Cedar Point                            19
# Kings Island                           19
# Six Flags Magic Mountain               17
# Hersheypark                            16
#                                      ...
# New York-New York Hotel and Casino      1
# Granada Studios Tour                    1
# Funtown Splashtown USA                  1
# Suzuka, Mie Prefecture, Japan           1
# Epcot                                   1
# Name: Location, Length: 280, dtype: int64

# %%
df1.query("Location!= 'Other'")
# Out:
#                                 Coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 5                             Cannon Coaster                    Coney Island
# 6                              Leap-The-Dips                   Lakemont Park
# ...                                      ...                             ...
# 1080                              Iron Gwazi         Busch Gardens Tampa Bay
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# # Temp

# %%
temp=df1.columns

# %%
temp
# Out:
# Index(['Coaster_name', 'Location', 'Status', 'Manufacturer', 'Year_introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_date_clean', 'Speed_mph',
#        'Height_value', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
'abc'.upper()
# Out:
# 'ABC'

# %%
t=[]
for i in temp:
    s=i[0].upper()+i[1:]
    t+=[s]

# %%
t
# Out:
# ['Coaster_name',
#  'Location',
#  'Status',
#  'Manufacturer',
#  'Year_introduced',
#  'Latitude',
#  'Longitude',
#  'Type',
#  'Opening_date_clean',
#  'Speed_mph',
#  'Height_value',
#  'Inversions_clean',
#  'Gforce_clean']

# %%
temp
# Out:
# Index(['Coaster_name', 'Location', 'Status', 'Manufacturer', 'Year_introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_date_clean', 'Speed_mph',
#        'Height_value', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
for i,j in zip(temp,t):
    print(i,j)
# Out:
# Coaster_name Coaster_name
# Location Location
# Status Status
# Manufacturer Manufacturer
# Year_introduced Year_introduced
# Latitude Latitude
# Longitude Longitude
# Type Type
# Opening_date_clean Opening_date_clean
# Speed_mph Speed_mph
# Height_value Height_value
# Inversions_clean Inversions_clean
# Gforce_clean Gforce_clean

# %%
d={}
for i,j in zip(temp,t):
    d[i]=j
print(d)
# Out:
# {'Coaster_name': 'Coaster_name', 'Location': 'Location', 'Status': 'Status', 'Manufacturer': 'Manufacturer', 'Year_introduced': 'Year_introduced', 'Latitude': 'Latitude', 'Longitude': 'Longitude', 'Type': 'Type', 'Opening_date_clean': 'Opening_date_clean', 'Speed_mph': 'Speed_mph', 'Height_value': 'Height_value', 'Inversions_clean': 'Inversions_clean', 'Gforce_clean': 'Gforce_clean'}

# %%
df1 = df1.rename(columns=d)

# %%
df1
# Out:
#                                 Coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...
